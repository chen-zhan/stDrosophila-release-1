# %% [markdown]
# # Nuclei segmentation

# %%
import gzip

import cv2
import matplotlib.pyplot as plt
import numpy as np
import skimage
import sklearn
import spateo as st
from scipy import ndimage

plt.rcParams['image.interpolation'] = 'none'
# %config InlineBackend.figure_format='retina'

tif = skimage.io.imread('/media/yao/Elements SE/BGI_Paper/mouse_diaphragm/lasso_pre/mouse_diaphragm_C1/mouse_diaphragm_C1_tif.tif')
total, exonic, intronic = st.read_bgi_agg('/media/yao/Elements SE/BGI_Paper/mouse_diaphragm/lasso_pre/mouse_diaphragm_C3.txt')
fig, axes = plt.subplots(ncols=4, figsize=(12, 3), tight_layout=True)
axes[0].imshow(tif)
axes[0].set_title('nuclei')
axes[1].imshow(total.A, vmin=0, vmax=5)
axes[1].set_title('total')
axes[2].imshow(exonic.A, vmin=0, vmax=5)
axes[2].set_title('exonic')
axes[3].imshow(intronic.A, vmin=0, vmax=5)
axes[3].set_title('intronic')
plt.show()
# Out:
# /home/yao/anaconda3/envs/BGIpy37_pytorch113/lib/python3.7/site-packages/geopandas/_compat.py:115: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string
# /home/yao/anaconda3/envs/BGIpy37_pytorch113/lib/python3.7/site-packages/spaghetti/network.py:36: FutureWarning: The next major release of pysal/spaghetti (2.0.0) will drop support for all ``libpysal.cg`` geometries. This change is a first step in refactoring ``spaghetti`` that is expected to result in dramatically reduced runtimes for network instantiation and operations. Users currently requiring network and point pattern input as ``libpysal.cg`` geometries should prepare for this simply by converting to ``shapely`` geometries.
#   warnings.warn(f"{dep_msg}", FutureWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_63037/507601722.py in <module>
#      19 axes[1].imshow(total.A, vmin=0, vmax=5)
#      20 axes[1].set_title('total')
# ---> 21 axes[2].imshow(exonic.A, vmin=0, vmax=5)
#      22 axes[2].set_title('exonic')
#      23 axes[3].imshow(intronic.A, vmin=0, vmax=5)
#
# AttributeError: 'NoneType' object has no attribute 'A'
